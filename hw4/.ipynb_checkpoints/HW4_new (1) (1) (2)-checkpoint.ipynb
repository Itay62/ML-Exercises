# %% [markdown]
# # Exercise 4: Logistic Regression, Bayes and EM
#
# In this assignment you will implement several algorithms as learned in class.
#
# ## Read the following instructions carefully:
#
# 1. This jupyter notebook contains all the step by step instructions needed for this exercise.
# 2. Write **efficient vectorized** code whenever possible. Some calculations in this exercise take several minutes when implemented efficiently, and might take much longer otherwise. Unnecessary loops will result in point deduction.
# 3. You are responsible for the correctness of your code and should add as many tests as you see fit. Tests will not be graded nor checked.
# 4. Write your functions in this notebook only. **Do not create Python modules and import them**.
# 5. You are allowed to use functions and methods from the [Python Standard Library](https://docs.python.org/3/library/) and [numpy](https://www.numpy.org/devdocs/reference/) and pandas.
# 6. Your code must run without errors. During the environment setup, you were given a specific version of `numpy` to install (1.15.4). Changes of the configuration we provided are at your own risk. Any code that cannot run will not be graded.
# 7. Write your own code. Cheating will not be tolerated.
# 8. Submission includes this notebook only with the exercise number and your ID as the filename. For example: `hw4_123456789_987654321.ipynb` if you submitted in pairs and `hw4_123456789.ipynb` if you submitted the exercise alone.
# 9. Answers to qualitative questions should be written in **markdown** cells (with $\LaTeX$ support). Answers that will be written in commented code blocks will not be checked.
#
# ## In this exercise you will perform the following:
# 1. Implement Logistic Regression algorithm.
# 1. Implement EM algorithm.
# 1. Implement Navie Bayes algorithm that uses EM for calculating the likelihood.
# 1. Visualize your results.

# %% [markdown]
# # I have read and understood the instructions: *** YOUR ID HERE ***

# %%
import numpy as np
import pandas as pd
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

# make matplotlib figures appear inline in the notebook
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Make the notebook automatically reload external python modules
# %load_ext autoreload
# %autoreload 2
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Function for ploting the decision boundaries of a model
# You will use it later
def plot_decision_regions(X, y, classifier, resolution=0.01):

    # setup marker generator and color map
    markers = ('.', '.')
    colors = ('blue', 'red')
    cmap = ListedColormap(colors[:len(np.unique(y))])
    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

# %% [markdown]
# ## Reading the data

# %%
training_set = pd.read_csv('training_set.csv')
test_set = pd.read_csv('test_set.csv')
X_training, y_training = training_set[['x1', 'x2']].values, training_set['y'].values
X_test, y_test = test_set[['x1', 'x2']].values, test_set['y'].values
print(np.isnan(X_training).any())
# Out:
# False

# %% [markdown]
# ## Visualizing the data
# (2 points each - 8 points total)
#
# Plot the following graphs for the training set:
#
# For the first feature only:
# 1. For the first 1000 data points plot a histogram for each class on the same graph (use bins=20, alpha=0.5).
# 1. For all the data points plot a histogram for each class on the same graph (use bins=40, alpha=0.5).
#
# For both features:
# 1. For the first 1000 data points plot a scatter plot where each class has different color
# 1. For all the data points plot a scatter plot where each class has different color

# %%
#first feature first 1000 data point histogram
x_1000 = training_set.values[0: 1000]
x_1000_0 =x_1000[np.where(x_1000[:,2] == 0)]
x_1000_0_first = x_1000_0[:,0]
x_1000_1 = x_1000[np.where(x_1000[:,2] == 1)]
x_1000_1_first = x_1000_1[:,0]

plt.hist(x_1000_0_first,bins = 20, alpha=0.5,color="red")
plt.hist(x_1000_1_first,bins = 20, alpha=0.5)
plt.title("Histogram for the first 1000 data points, for each class ")
plt.ylabel("Frequency")
plt.xlabel("Values")
labels= ["Class 0","Class 1"]
plt.legend(labels)
fig1 = plt.figure()

#first feature all data points histogram
x_0 = training_set.values[np.where(training_set.values[:,2] == 0)]
x_0_first = x_0[:,0]
x_1 = training_set.values[np.where(training_set.values[:,2] == 1)]
x_1_first = x_1[:,0]

plt.hist(x_0_first,bins = 40, alpha=0.5,color="red")
plt.hist(x_1_first,bins = 40, alpha=0.5)
plt.title("Histogram for all the data points, for each class ")
plt.ylabel("Frequency")
plt.xlabel("Values")
labels= ["Class 0","Class 1"]
plt.legend(labels)
fig2 = plt.figure()

#Both feature, first 1000 data point scatter plot

plt.figure(figsize=(6, 6), dpi=80)
s_1000 = training_set.values[0: 1000]
s_1000_0 =s_1000[np.where(s_1000[:,2] == 0)]
s_1000_1 = s_1000[np.where(s_1000[:,2] == 1)]

s_1000_0_x1 =s_1000_0[:,0] 
s_1000_0_x2 =s_1000_0[:,1] 
s_1000_1_x1 =s_1000_1[:,0] 
s_1000_1_x2 =s_1000_1[:,1] 

plt.scatter(s_1000_0_x1,s_1000_0_x2,s=10, color="blue", alpha=0.5)
plt.scatter(s_1000_1_x1,s_1000_1_x2,s=10, color="red", alpha=0.5)
plt.title("Both feature, first 1000 data point scatter plot")
plt.ylabel("Second feature")
plt.xlabel("First feature")
labels= ["Class 0","Class 1"]
plt.legend(labels)
plt.show()
 #Both feature,all the data points scatter plot 
plt.figure(figsize=(6, 6), dpi=80)
x_0 = training_set.values[np.where(training_set.values[:,2] == 0)]
x_0_x1 = x_0[:,0]
x_0_x2 = x_0[:,1]

x_1 = training_set.values[np.where(training_set.values[:,2] == 1)]
x_1_x1 = x_1[:,0]
x_1_x2 = x_1[:,1]

plt.scatter(x_0_x1,x_0_x2,s=10, color="blue", alpha=0.5)
plt.scatter(x_1_x1,x_1_x2,s=10, color="red", alpha=0.5)
plt.title("Both feature,all the data points scatter plot ")
plt.ylabel("Second feature")
plt.xlabel("First feature")
labels= ["Class 0","Class 1"]
plt.legend(labels)
plt.show()

# %% [markdown]
# ## Logistic Regression
#
# (15 Points)
#
# Implement the Logistic Regression algorithm that uses gradient descent for finding the optimal theta vector.
#
# Where:
# $$
# h_\theta(x) = \frac{1}{1 + e^{-\theta^T x}}
# $$
#
# $$
# J(\theta)=\frac{1}{m} \sum_{d=1}^{m} - y^{(d)}ln(h_\theta(x^{(d)}) - (1 - y^{(d)})ln(1 - h_\theta(x^{(d)})
# $$
#
# Your class should contain the following functions:
# 1. fit - the learning function
# 1. predict - the function for predicting an instance after the fit function was executed
#
# \* You can add more functions if you think this is necessary
#
# Your model should also store a list of the costs that you've calculated in each iteration

# %%
def bias_trick(X):
    ones = np.ones(X.shape[0], dtype=int)
    return np.column_stack((ones,X))

# %%
class LogisticRegressionGD(object):
    """
    Logistic Regression Classifier using gradient descent.

    Parameters
    ------------
    eta : float
      Learning rate (between 0.0 and 1.0)
    n_iter : int
      Passes over the training dataset.
    eps : float
      minimal change in the cost to declare convergence
    random_state : int
      Random number generator seed for random weight
      initialization.
    """
    
    def __init__(self, eta=0.00005, n_iter=10000, eps=0.000001, random_state=42):
        self.eta = eta
        self.n_iter = n_iter
        self.eps = eps
        self.random_state = random_state
        self.theta = []
        self.J_history = []

    def fit(self, X, y):
        """ 
        Fit training data (the learning phase).
        Updating the theta vector in each iteration using gradient descent.
        Store the theta vector in an attribute of the LogisticRegressionGD object.
        Stop the function when the difference between the previous cost and the current is less than eps
        or when you reach n_iter.

        Parameters
        ----------
        X : {array-like}, shape = [n_examples, n_features]
          Training vectors, where n_examples is the number of examples and
          n_features is the number of features.
        y : array-like, shape = [n_examples]
          Target values.

        """
        X = bias_trick(X)
        np.random.seed(self.random_state)
        self.theta = np.random.random(X.shape[1])
        m = X.shape[0]
        for i in range(self.n_iter):
            cost = self.compute_cost(X, y, self.theta)
            if  i > 0 and (abs(self.J_history[-1] - cost) < self.eps):
                break    
            self.J_history.append(cost)
            h = self.hipo(X, self.theta)
            self.theta -= ((self.eta)*(X.T.dot(h-y)))  
        return self.theta, self.J_history
        
    def predict(self, X):
        """Return the predicted class label"""
        h = self.hipo(X, self.theta)
        if h > 0.5:
            return 1
        else:
            return 0

    
    def hipo(self, X, theta):
        theta_t = np.transpose(theta)
        dot_X_theta = np.dot(X, theta_t)
        e = np.exp(dot_X_theta)
        hipo = np.divide(e, 1 + e)
        return hipo
            
    def compute_cost(self, X, y, theta):
        J = 0
        h = self.hipo(X, theta)
        m = np.shape(np.array(X))[0]
        J = (np.sum( (-y * np.log(h) ) - 
                            ( (1 - y) * np.log(1 - h) ) ) ) / m
        return J

# %%
def compute_accuracy_logistic(validation_set, logisticRegressionGD):
    """
    Compute the accuracy of a given a testset using a LogisticRegressionGD object.
    
    Input
        - testset: The testset for which to compute the accuracy (Numpy array). compoed by class labels
        - logisticRegressionGD : A logisticRegressionGD object capable of prediciting the class for each instance in the testset.
        
    Ouput
        - Accuracy = #Correctly Classified / #testset size
    """
    correct_count = 0
    validation_set_x, validation_set_y = validation_set[:,:2], validation_set[:,-1]
    validation_set_x = bias_trick(validation_set_x)
    for i in range(len(validation_set_x)):
        if logisticRegressionGD.predict(validation_set_x[i]) == validation_set_y[i]: # if prediction is correct increase counter
            correct_count = correct_count + 1
    return  correct_count / len(validation_set)

# %%
logisticRegressionGD = LogisticRegressionGD()
t, J = logisticRegressionGD.fit(X_training, y_training)
print(compute_accuracy_logistic(test_set.values, logisticRegressionGD))
# Out:
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [0.37454012 0.95071431 0.73199394]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [0.37454012 0.95071431 0.73199394]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [0.32095337 0.83684545 0.43217945]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [0.32095337 0.83684545 0.43217945]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [0.27787693 0.68697537 0.20744195]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [0.27787693 0.68697537 0.20744195]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [0.2470628  0.50207297 0.07642523]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [0.2470628  0.50207297 0.07642523]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.22281172  0.31426769 -0.00829382]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.22281172  0.31426769 -0.00829382]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.20506391  0.15030995 -0.05587643]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.20506391  0.15030995 -0.05587643]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.19495545  0.03393248 -0.06724758]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.19495545  0.03393248 -0.06724758]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.18913564 -0.03645361 -0.06640026]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.18913564 -0.03645361 -0.06640026]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.1848541  -0.07713708 -0.06668418]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.1848541  -0.07713708 -0.06668418]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.18148766 -0.10088402 -0.0674415 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.18148766 -0.10088402 -0.0674415 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.17870537 -0.11502517 -0.06803736]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.17870537 -0.11502517 -0.06803736]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.17628645 -0.12357378 -0.06839045]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.17628645 -0.12357378 -0.06839045]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.17409416 -0.12878615 -0.06854207]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.17409416 -0.12878615 -0.06854207]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.17204431 -0.13197313 -0.06854958]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.17204431 -0.13197313 -0.06854958]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.17008487 -0.13391609 -0.06846025]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.17008487 -0.13391609 -0.06846025]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.16818354 -0.13508921 -0.06830788]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.16818354 -0.13508921 -0.06830788]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.1663202  -0.13578366 -0.06811524]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.1663202  -0.13578366 -0.06811524]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.16448228 -0.1361796  -0.06789721]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.16448228 -0.1361796  -0.06789721]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.16266193 -0.13638906 -0.06766336]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.16266193 -0.13638906 -0.06766336]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.16085422 -0.13648193 -0.06741977]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.16085422 -0.13648193 -0.06741977]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15905608 -0.13650189 -0.06717029]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15905608 -0.13650189 -0.06717029]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15726556 -0.13647626 -0.06691735]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15726556 -0.13647626 -0.06691735]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15548143 -0.13642217 -0.06666247]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15548143 -0.13642217 -0.06666247]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15370295 -0.13635032 -0.06640661]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15370295 -0.13635032 -0.06640661]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15192962 -0.13626744 -0.06615038]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15192962 -0.13626744 -0.06615038]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15016113 -0.13617776 -0.06589415]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.15016113 -0.13617776 -0.06589415]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.14839728 -0.1360839  -0.06563816]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.14839728 -0.1360839  -0.06563816]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.14663796 -0.13598752 -0.06538254]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.14663796 -0.13598752 -0.06538254]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.14488307 -0.13588966 -0.06512741]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.14488307 -0.13588966 -0.06512741]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.14313256 -0.13579098 -0.06487281]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.14313256 -0.13579098 -0.06487281]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.14138639 -0.13569187 -0.06461877]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.14138639 -0.13569187 -0.06461877]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13964453 -0.1355926  -0.06436533]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13964453 -0.1355926  -0.06436533]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13790696 -0.13549332 -0.06411248]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13790696 -0.13549332 -0.06411248]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13617367 -0.13539414 -0.06386025]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13617367 -0.13539414 -0.06386025]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13444463 -0.13529511 -0.06360863]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13444463 -0.13529511 -0.06360863]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13271984 -0.13519629 -0.06335762]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13271984 -0.13519629 -0.06335762]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13099927 -0.13509768 -0.06310723]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.13099927 -0.13509768 -0.06310723]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12928294 -0.1349993  -0.06285746]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12928294 -0.1349993  -0.06285746]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12757081 -0.13490117 -0.0626083 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12757081 -0.13490117 -0.0626083 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12586288 -0.13480329 -0.06235976]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12586288 -0.13480329 -0.06235976]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12415914 -0.13470566 -0.06211183]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12415914 -0.13470566 -0.06211183]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12245958 -0.13460829 -0.06186451]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12245958 -0.13460829 -0.06186451]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12076418 -0.13451117 -0.0616178 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.12076418 -0.13451117 -0.0616178 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.11907295 -0.1344143  -0.0613717 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.11907295 -0.1344143  -0.0613717 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.11738587 -0.13431769 -0.06112621]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.11738587 -0.13431769 -0.06112621]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.11570292 -0.13422134 -0.06088133]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.11570292 -0.13422134 -0.06088133]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.1140241  -0.13412524 -0.06063705]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.1140241  -0.13412524 -0.06063705]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.1123494  -0.13402939 -0.06039338]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.1123494  -0.13402939 -0.06039338]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.11067881 -0.13393379 -0.0601503 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.11067881 -0.13393379 -0.0601503 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.10901232 -0.13383845 -0.05990783]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.10901232 -0.13383845 -0.05990783]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.10734992 -0.13374336 -0.05966596]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.10734992 -0.13374336 -0.05966596]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.1056916  -0.13364852 -0.05942468]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.1056916  -0.13364852 -0.05942468]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.10403734 -0.13355394 -0.059184  ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.10403734 -0.13355394 -0.059184  ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.10238714 -0.1334596  -0.05894392]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.10238714 -0.1334596  -0.05894392]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.100741   -0.13336551 -0.05870443]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.100741   -0.13336551 -0.05870443]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.09909889 -0.13327167 -0.05846553]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.09909889 -0.13327167 -0.05846553]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.09746081 -0.13317807 -0.05822722]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.09746081 -0.13317807 -0.05822722]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.09582675 -0.13308473 -0.0579895 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.09582675 -0.13308473 -0.0579895 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.09419671 -0.13299163 -0.05775236]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.09419671 -0.13299163 -0.05775236]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.09257066 -0.13289877 -0.05751581]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.09257066 -0.13289877 -0.05751581]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.0909486  -0.13280616 -0.05727985]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.0909486  -0.13280616 -0.05727985]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08933053 -0.1327138  -0.05704447]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08933053 -0.1327138  -0.05704447]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08771642 -0.13262167 -0.05680967]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08771642 -0.13262167 -0.05680967]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08610628 -0.13252979 -0.05657546]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08610628 -0.13252979 -0.05657546]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08450009 -0.13243816 -0.05634182]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08450009 -0.13243816 -0.05634182]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08289784 -0.13234676 -0.05610875]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08289784 -0.13234676 -0.05610875]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08129952 -0.13225561 -0.05587627]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.08129952 -0.13225561 -0.05587627]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07970513 -0.13216469 -0.05564436]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07970513 -0.13216469 -0.05564436]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07811465 -0.13207402 -0.05541302]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07811465 -0.13207402 -0.05541302]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07652807 -0.13198358 -0.05518225]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07652807 -0.13198358 -0.05518225]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07494539 -0.13189338 -0.05495206]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07494539 -0.13189338 -0.05495206]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.0733666  -0.13180342 -0.05472243]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.0733666  -0.13180342 -0.05472243]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07179168 -0.1317137  -0.05449337]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07179168 -0.1317137  -0.05449337]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07022063 -0.13162421 -0.05426488]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.07022063 -0.13162421 -0.05426488]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06865343 -0.13153496 -0.05403695]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06865343 -0.13153496 -0.05403695]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06709008 -0.13144594 -0.05380958]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06709008 -0.13144594 -0.05380958]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06553057 -0.13135716 -0.05358278]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06553057 -0.13135716 -0.05358278]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06397489 -0.13126861 -0.05335653]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06397489 -0.13126861 -0.05335653]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06242303 -0.13118029 -0.05313085]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06242303 -0.13118029 -0.05313085]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06087497 -0.13109221 -0.05290572]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.06087497 -0.13109221 -0.05290572]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05933072 -0.13100436 -0.05268115]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05933072 -0.13100436 -0.05268115]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05779026 -0.13091674 -0.05245714]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05779026 -0.13091674 -0.05245714]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05625359 -0.13082935 -0.05223368]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05625359 -0.13082935 -0.05223368]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05472068 -0.13074219 -0.05201077]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05472068 -0.13074219 -0.05201077]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05319154 -0.13065525 -0.05178841]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05319154 -0.13065525 -0.05178841]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05166616 -0.13056855 -0.0515666 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
#  [ 1.          4.16906648  1.64874303]]
# [ 0.05166616 -0.13056855 -0.0515666 ]
# [[ 1.         -1.38578869  9.13146361]
#  [ 1.         -2.23690338  5.56117803]
#  [ 1.         -2.3625238   5.2159729 ]
#  ...
#  [ 1.          7.42420048  1.77493117]
#  [ 1.          6.67073987  0.33570079]
# ...
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.56142792 4.69344865]
# [1.         5.56142792 4.69344865]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.88549372 2.89993882]
# [1.         5.88549372 2.89993882]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.66661146 3.19068866]
# [1.         4.66661146 3.19068866]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.33590138 3.4628319 ]
# [1.         6.33590138 3.4628319 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.58489178 2.68441974]
# [1.         6.58489178 2.68441974]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.30238713 2.82587616]
# [1.         5.30238713 2.82587616]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.80500589 1.73625611]
# [1.         4.80500589 1.73625611]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          5.74163479 -0.54283047]
# [ 1.          5.74163479 -0.54283047]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.20925941 3.71913399]
# [1.         6.20925941 3.71913399]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.57260338 1.12601598]
# [1.         6.57260338 1.12601598]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.25931415 2.65088148]
# [1.         5.25931415 2.65088148]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.74532566 1.08966356]
# [1.         6.74532566 1.08966356]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.70367436 0.9108865 ]
# [1.         7.70367436 0.9108865 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.71789587 3.94407874]
# [1.         4.71789587 3.94407874]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          5.26866693 -2.05054065]
# [ 1.          5.26866693 -2.05054065]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.42744285 2.14172802]
# [1.         6.42744285 2.14172802]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.37656363 0.03419255]
# [1.         5.37656363 0.03419255]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.73820936 4.2500717 ]
# [1.         6.73820936 4.2500717 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.00806808 1.90125803]
# [1.         5.00806808 1.90125803]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.78705693 1.60952768]
# [1.         5.78705693 1.60952768]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.68778343 1.81776126]
# [1.         5.68778343 1.81776126]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.43138801 1.28437364]
# [1.         6.43138801 1.28437364]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.04901733 1.98888384]
# [1.         5.04901733 1.98888384]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.62555728 1.30065261]
# [1.         6.62555728 1.30065261]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          6.04704706 -0.2694996 ]
# [ 1.          6.04704706 -0.2694996 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.93250345 1.30532387]
# [1.         5.93250345 1.30532387]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.04136901 3.14710009]
# [1.         7.04136901 3.14710009]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.75634866 0.36352929]
# [1.         5.75634866 0.36352929]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.27299542 1.40455069]
# [1.         7.27299542 1.40455069]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.26941565 3.38901647]
# [1.         7.26941565 3.38901647]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.38333634 0.63523152]
# [1.         5.38333634 0.63523152]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.8240393  1.35921056]
# [1.         6.8240393  1.35921056]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.2079652  3.06205654]
# [1.         5.2079652  3.06205654]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.40077342 0.83513215]
# [1.         5.40077342 0.83513215]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.25064972 0.94842486]
# [1.         6.25064972 0.94842486]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.06861742 4.25521712]
# [1.         5.06861742 4.25521712]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.08190509 3.67794428]
# [1.         5.08190509 3.67794428]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.31076996 3.37686405]
# [1.         6.31076996 3.37686405]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.49729005 1.55664796]
# [1.         5.49729005 1.55664796]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.4646583  0.25190603]
# [1.         4.4646583  0.25190603]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.55200194 1.27708806]
# [1.         7.55200194 1.27708806]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.59927909 3.06580504]
# [1.         5.59927909 3.06580504]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.55823963 0.94680414]
# [1.         4.55823963 0.94680414]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.17941511 3.34447273]
# [1.         6.17941511 3.34447273]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         8.82650729 1.01400764]
# [1.         8.82650729 1.01400764]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          7.04762807 -0.37767298]
# [ 1.          7.04762807 -0.37767298]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.30420459 1.3827456 ]
# [1.         5.30420459 1.3827456 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          7.35684202 -0.16703515]
# [ 1.          7.35684202 -0.16703515]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.24077237 0.42561298]
# [1.         6.24077237 0.42561298]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.88706177 3.5923555 ]
# [1.         5.88706177 3.5923555 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.60499582 0.38761985]
# [1.         4.60499582 0.38761985]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          7.35330783 -0.87083758]
# [ 1.          7.35330783 -0.87083758]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.05518159 1.26592403]
# [1.         6.05518159 1.26592403]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.9267535  1.75860501]
# [1.         5.9267535  1.75860501]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.22562082 0.41569138]
# [1.         6.22562082 0.41569138]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.43285576 2.05347733]
# [1.         4.43285576 2.05347733]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.51605844 4.35651784]
# [1.         5.51605844 4.35651784]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.39700642 1.86731658]
# [1.         4.39700642 1.86731658]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.98680756 2.79624399]
# [1.         6.98680756 2.79624399]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.6992838  1.07793281]
# [1.         6.6992838  1.07793281]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.12016278 2.10782061]
# [1.         5.12016278 2.10782061]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.39161203 2.80735948]
# [1.         6.39161203 2.80735948]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.39194959 2.44608686]
# [1.         5.39194959 2.44608686]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.73819256 5.02885946]
# [1.         5.73819256 5.02885946]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.28144323 1.63236393]
# [1.         5.28144323 1.63236393]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.85910134 3.10180215]
# [1.         4.85910134 3.10180215]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.66979553 0.51492279]
# [1.         5.66979553 0.51492279]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.53401304 2.26676108]
# [1.         7.53401304 2.26676108]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.46640252 0.38206977]
# [1.         5.46640252 0.38206977]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          4.88243351 -0.28595212]
# [ 1.          4.88243351 -0.28595212]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.97520297 3.89435606]
# [1.         5.97520297 3.89435606]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.67086498 4.35774742]
# [1.         7.67086498 4.35774742]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.28540625 3.77787026]
# [1.         7.28540625 3.77787026]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.15256066 5.42807583]
# [1.         5.15256066 5.42807583]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         3.95421034 3.94222723]
# [1.         3.95421034 3.94222723]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.14783267 3.15212039]
# [1.         5.14783267 3.15212039]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.87238644 1.69417491]
# [1.         5.87238644 1.69417491]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.63510574 5.52937569]
# [1.         5.63510574 5.52937569]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.20653678 2.61808939]
# [1.         6.20653678 2.61808939]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.2072693  3.81479974]
# [1.         6.2072693  3.81479974]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         8.23571339 0.98444663]
# [1.         8.23571339 0.98444663]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.19939093 0.57537881]
# [1.         7.19939093 0.57537881]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.30681811 0.1434863 ]
# [1.         6.30681811 0.1434863 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.22834819 2.08743288]
# [1.         5.22834819 2.08743288]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.35914357 1.7843737 ]
# [1.         6.35914357 1.7843737 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.83786208 1.65038463]
# [1.         6.83786208 1.65038463]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.21498012 5.37604232]
# [1.         6.21498012 5.37604232]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          6.63760945 -0.63547442]
# [ 1.          6.63760945 -0.63547442]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.29470787 0.31610303]
# [1.         5.29470787 0.31610303]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.55991667 2.51679951]
# [1.         7.55991667 2.51679951]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.50509192 3.48668555]
# [1.         4.50509192 3.48668555]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.07925174 3.62051876]
# [1.         6.07925174 3.62051876]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.66153002 1.23831352]
# [1.         5.66153002 1.23831352]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.56635987 1.56354382]
# [1.         6.56635987 1.56354382]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         3.91285298 3.47118022]
# [1.         3.91285298 3.47118022]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.95610909 3.44593922]
# [1.         5.95610909 3.44593922]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.69309145 1.02077703]
# [1.         7.69309145 1.02077703]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.60565485 1.5260168 ]
# [1.         7.60565485 1.5260168 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.65633076 2.62203139]
# [1.         5.65633076 2.62203139]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.09965699 2.9226666 ]
# [1.         5.09965699 2.9226666 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.26920597 2.32923046]
# [1.         7.26920597 2.32923046]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.23409924 2.65043539]
# [1.         5.23409924 2.65043539]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          5.88117472 -0.16166941]
# [ 1.          5.88117472 -0.16166941]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         8.00782094 2.9925218 ]
# [1.         8.00782094 2.9925218 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.34151316 1.1999296 ]
# [1.         5.34151316 1.1999296 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.51948996 2.23841785]
# [1.         4.51948996 2.23841785]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.27701843 4.74467608]
# [1.         4.27701843 4.74467608]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.58693474 2.68048829]
# [1.         5.58693474 2.68048829]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.89809176 2.58959664]
# [1.         6.89809176 2.58959664]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.40879535 1.4906804 ]
# [1.         6.40879535 1.4906804 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.06865562 2.72203342]
# [1.         7.06865562 2.72203342]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.        5.1563269 3.8727182]
# [1.        5.1563269 3.8727182]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.51514394 2.31665035]
# [1.         7.51514394 2.31665035]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.34724674 1.26636654]
# [1.         5.34724674 1.26636654]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.0588112  3.47130643]
# [1.         4.0588112  3.47130643]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          6.81745493 -1.30060267]
# [ 1.          6.81745493 -1.30060267]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          6.16496964 -2.38409375]
# [ 1.          6.16496964 -2.38409375]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.61734232 2.38634681]
# [1.         6.61734232 2.38634681]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.32158118 4.40902794]
# [1.         5.32158118 4.40902794]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          6.50188767 -0.28061906]
# [ 1.          6.50188767 -0.28061906]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.01248363 2.80561117]
# [1.         5.01248363 2.80561117]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.39295424 2.30006388]
# [1.         6.39295424 2.30006388]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.69504355 0.80143621]
# [1.         6.69504355 0.80143621]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.08080696 0.70673116]
# [1.         6.08080696 0.70673116]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.43446885 3.64353027]
# [1.         5.43446885 3.64353027]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.72190188 2.95015594]
# [1.         4.72190188 2.95015594]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.72404627 1.20337309]
# [1.         6.72404627 1.20337309]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.98695082 3.16221478]
# [1.         6.98695082 3.16221478]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.19136409 1.80545524]
# [1.         7.19136409 1.80545524]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.43496513 0.37253999]
# [1.         5.43496513 0.37253999]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.4906944  1.85033798]
# [1.         7.4906944  1.85033798]
# [-0.44267327 -0.10325018  0.0201196 ]
# [ 1.          4.93036106 -0.43016646]
# [ 1.          4.93036106 -0.43016646]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.43049797 0.74185636]
# [1.         6.43049797 0.74185636]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.69904782 1.20504421]
# [1.         5.69904782 1.20504421]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.05836013 4.440778  ]
# [1.         6.05836013 4.440778  ]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.297389   4.00727974]
# [1.         7.297389   4.00727974]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.89547857 3.51983741]
# [1.         4.89547857 3.51983741]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.55657866 0.74827344]
# [1.         5.55657866 0.74827344]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.53349166 1.69671624]
# [1.         5.53349166 1.69671624]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.14467538 2.52407966]
# [1.         5.14467538 2.52407966]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         3.90454285 3.53002199]
# [1.         3.90454285 3.53002199]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.29557104 0.43211521]
# [1.         6.29557104 0.43211521]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         6.46716392 1.10800116]
# [1.         6.46716392 1.10800116]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         4.0464087  3.56374164]
# [1.         4.0464087  3.56374164]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         7.3750252  1.97471887]
# [1.         7.3750252  1.97471887]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.86795847 1.15656835]
# [1.         5.86795847 1.15656835]
# [-0.44267327 -0.10325018  0.0201196 ]
# [1.         5.29507349 0.9360772 ]
# [1.         5.29507349 0.9360772 ]
# [-0.44267327 -0.10325018  0.0201196 ]
# 0.804

# %% [markdown]
# ## Cross Validation
#
# (5 points)
#
# Use 5-fold cross validation in order to find the best eps and eta params from the given lists.
#
# Shuffle the training set before you split the data to the folds.

# %%
etas = [0.05, 0.005, 0.0005, 0.00005, 0.000005]
epss = [0.01, 0.001, 0.0001, 0.00001, 0.000001]

def best_param(X): ## Finds best pair
    acc_dict = {}
    dataset_split = cross_validation_split(X)
    for eta in etas:
        for eps in epss:
            logisticRegressionGD = LogisticRegressionGD(eta=eta, n_iter=10000, eps=eps, random_state=42)
            acc_count = 0
            for i in range(len(dataset_split)):
                dataset_split_copy = dataset_split.copy()
                validation_set = dataset_split_copy[i]
                dataset_split_copy.pop(i)
                united_dataset = dataset_split_copy[0]
                for j in range(1, len(dataset_split_copy)):           ## Concatenating all data without validation set
                    united_dataset = np.concatenate((united_dataset, dataset_split_copy[j]))
                    
                X_training, y_training = united_dataset[:,:2], united_dataset[:,-1]
                logisticRegressionGD.J_history = []
                theta, J_history = logisticRegressionGD.fit(X_training, y_training)
                acc_count += compute_accuracy_logistic(validation_set, logisticRegressionGD)
                print(acc_count)
            avrage_acc = acc_count / len(dataset_split)
            acc_dict.update({(eta,eps) : avrage_acc})
    max_key = max(acc_dict, key=acc_dict.get)
    return max_key

def cross_validation_split(dataset, folds=5): ## Splitting the dataset into 5 folds
    np.random.shuffle(dataset)
    dataset_split = []
    dataset_split = np.array_split(dataset, folds)  
    return dataset_split

# %%
best_params = best_param(training_set.values)
print(best_params)
# Out:
# 0.715
# 1.345
# 2.0725
# 2.6525
# 3.2399999999999998
# 0.715
# 1.345
# 2.0725
# 2.6525
# 3.2399999999999998
# 0.715
# 1.345
# 2.0725
# 2.6525
# 3.2399999999999998
# 0.715
# 1.345
# 2.0725
# 2.6525
# 3.2399999999999998
# 0.715
# 1.345
# 2.0725
# 2.6525
# 3.2399999999999998
# 0.585
# 1.2275
# 1.53
# 2.11
# 2.6975
# 0.585
# 1.2275
# 1.53
# 2.11
# 2.6975
# 0.585
# 1.2275
# 1.53
# 2.11
# 2.6975
# 0.585
# 1.2275
# 1.53
# 2.11
# 2.6975
# 0.585
# 1.2275
# 1.53
# 2.11
# 2.6975
# 0.315
# 0.6725
# 0.985
# 1.35
# 1.7075
# 0.315
# 0.6725
# 0.985
# 1.35
# 1.7075
# 0.315
# 0.6725
# 0.985
# 1.35
# 1.7075
# 0.315
# 0.6725
# 0.985
# 1.35
# 1.7075
# 0.315
# 0.6725
# 0.985
# 1.35
# 1.7075
# 0.5775
# 1.185
# 1.8
# 2.3525
# 2.9075
# 0.6375
# 1.3175
# 1.9549999999999998
# 2.585
# 3.215
# 0.6325
# 1.31
# 1.96
# 2.5925
# 3.2249999999999996
# 0.6325
# 1.3175
# 1.9699999999999998
# 2.61
# 3.245
# 0.6275
# 1.3125
# 1.9649999999999999
# 2.6075
# 3.245
# 0.4325
# 0.8225
# 1.215
# 1.6500000000000001
# 2.0825
# 0.5775
# 1.1875
# 1.8050000000000002
# 2.3525
# 2.9075
# 0.63
# 1.2925
# 1.9125
# 2.5325
# 3.1625
# 0.6375
# 1.305
# 1.95
# 2.5825
# 3.2075
# 0.6325
# 1.315
# 1.9674999999999998
# 2.6049999999999995
# 3.2399999999999993
# (5e-05, 1e-05)

# %% [markdown]
# ## Normal distribution pdf
#
# (2 Points)
#
# Implement the normal distribution pdf
# $$
# f(x;\mu,\sigma) = \frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{1}{2}\big{(}\frac{x-\mu}{\sigma}\big{)}^2}
# $$
# Write an efficient vectorized code

# %%
# calc normal pdf    
def norm_pdf(data, mu, sigma):
  
    x_minus_std_square = (np.subtract(data, mu)) ** 2
    std_square_times_2 = np.multiply(sigma ** 2,2)
    power = -np.divide(x_minus_std_square, std_square_times_2)
    right = np.exp(power)
    denominator = np.multiply(std_square_times_2, np.pi)
    left = np.divide(1, np.sqrt(denominator))
    result = np.multiply(left, right)
    
    return result

# %% [markdown]
# ## Expectation Maximization
#
# (15 Points)
#
# Implement the Expectation Maximization algorithm for gaussian mixture model.
#
# The class should hold the distribution params.
#
# Use -log likelihood as the cost function:
# $$
# cost(x) = \sum_{d=1}^{m}-log(w * pdf(x; \mu, \sigma))
# $$
#
# \* The above is the cost of one gaussian. Think how to use the cost function for gaussian mixture.
#
# Your class should contain the following functions:
# 1. init_params - initialize distribution params
# 1. expectation - calculating responsibilities
# 1. maximization - updating distribution params
# 1. fit - the learning function
# 1. get_dist_params - return the distribution params
#
# \* You can add more functions if you think this is necessary
#
# Don't change the eps params (eps=0.01)
#
# When you need to calculate the pdf of a normal distribution use the function `norm_pdf` that you implemented above.

# %%
class EM(object):
    """
    Naive Bayes Classifier using Gauusian Mixture Model (EM) for calculating the likelihood.

    Parameters
    ------------
    k : int
      Number of gaussians in each dimension
    n_iter : int
      Passes over the training dataset in the EM proccess
    eps: float
      minimal change in the cost to declare convergence
    random_state : int
      Random number generator seed for random params initialization.
    """
    
    def __init__(self, k=2, n_iter=1000, eps=0.01,random_state=42):
        self.k = k
        self.n_iter = n_iter
        self.eps = eps
        self.random_state=random_state
        self.mu = []
        self.sigma = []
        self.weight = []
        self.responsibilities = [[]] * self.k

        
    # initial guesses for parameters
    def init_params(self, data):
        """
        Initialize distribution params
        """
        np.random.seed(self.random_state)
        self.mu = np.random.random(self.k)
        self.sigma = np.random.random(self.k)
        self.weight = np.ones((self.k, 1), dtype=np.float32) / self.k
        #self.responsibilities = np.ones([len(data), self.k])
     
        
    def expectation(self, data):
        """
        E step - calculating responsibilities
        """
        sum_responsibilities = 0
        self.responsibilities = [[]] * self.k
        for k in range(self.k):
            sum_responsibilities += self.weight[k] * norm_pdf(data, self.mu[k], self.sigma[k])
        for k in range(self.k):
            self.responsibilities[k] = self.weight[k] * norm_pdf(data, self.mu[k], self.sigma[k]) / sum_responsibilities
            
        return self.responsibilities
    
    
    def maximization(self, data):
        """
        M step - updating distribution params
        """
        length_of_data = len(data)
        for j in range(self.k):
        
            self.weight[j] = np.divide(np.nansum(self.responsibilities[j]), length_of_data) ## new weight
            self.mu[j] = np.divide(np.dot((self.responsibilities[j]), data), length_of_data * self.weight[j])  ## new mean 
            self.sigma[j] = np.sqrt( np.divide(np.dot( (self.responsibilities[j]), np.square(np.subtract(data, self.mu[j]))), length_of_data * self.weight[j])) ## new sigma
       
    def fit(self, data):
        """ 
        Fit training data (the learning phase).
        Use init_params and then expectation and maximization function in order to find params 
        for the distribution. 
        Store the params in attributes of the EM object.
        Stop the function when the difference between the previous cost and the current is less than eps
        or when you reach n_iter.
        """
        self.init_params(data)
        cost_history = []
        cost_history.append(self.cost(data))
        
        for i in range(1, self.n_iter):
            #training the data
            self.expectation(data)
            self.maximization(data)
            
            #checking costs
            cost_history.append(self.cost(data))
            if (abs(cost_history[i] - cost_history[i-1]) ) < self.eps:
               
                break;
    
    def get_dist_params(self):
        return self.weight, self.mu, self.sigma 
    
    def cost(self, data):
        cost = 0
        for k in range(self.k):
            helper = 0
            for i in range(len(data)):
                helper += self.weight[k] * norm_pdf(data[i], self.mu[k], self.sigma[k])
            cost += -np.log(helper)
        return cost

# %%
em1 = EM()
#em1.init_params(X_training[:,1])
em1.fit(X_training[:,0])
print(em1.get_dist_params())
#print(em1.expectation(X_training[:,1]))
#print(em1.maximization(X_training[:,1]))

#em1.fit(X_training[:,1])
#print(em1.get_dist_params())
# Out:
# (array([[0.49960792],
#        [0.5003921 ]], dtype=float32), array([-2.95995903,  4.64321327]), array([1.42549372, 1.37235057]))

# %% [markdown]
# ## Naive Bayes
#
# (15 Points)
#
# Implement the Naive Bayes algorithm.
#
# For calculating the likelihood use the EM algorithm that you implemented above to find the distribution params. With these params you can calculate the likelihood probability.
#
# Calculate the prior probability directly from the training set.
#
# Your class should contain the following functions:
# 1. fit - the learning function
# 1. predict - the function for predicting an instance (or instances) after the fit function was executed
#
# \* You can add more functions if you think this is necessary

# %%
class NaiveBayesGaussian(object):
    """
    Naive Bayes Classifier using Gauusian Mixture Model (EM) for calculating the likelihood.

    Parameters
    ------------
    k : int
      Number of gaussians in each dimension
    random_state : int
      Random number generator seed for random params initialization.
    """
    
     
    def __init__(self, k=2):
        self.k = k
        self.params_dict = {} #(label,feature index):(weight, mu, sigma)
        self.posteriors = []
        self.labels = []
        self.count = []
        self.len_data = 0
        
    def fit(self, X,y):
        """ 
        Fit training data.

        Parameters
        ----------
        X : array-like, shape = [n_examples, n_features]
          Training vectors, where n_examples is the number of examples and
          n_features is the number of features.
        y : array-like, shape = [n_examples]
          Target values.
        """
        
        self.len_data = len(X)
        self.labels,self.count = np.unique(y,return_counts=True)
        for label in self.labels:
            for i in range(np.shape(X)[1]):
                feature_data = X[:,i] #column feature
                feature_and_class = feature_data[np.where(y == label)]
                em = EM()
                em.fit(feature_and_class)
                weight, mu, sigma = em.get_dist_params()
                self.params_dict[(label,i)] = (weight, mu, sigma)
                
        return self.params_dict
        
    
    def get_instance_likelihood_for_label(self,X,label):
       
        for i in range(len(X)):
            pdf = 0
            likelihood = 1
            params = self.params_dict.get((label,i))
            for j in range(len(params[0])):
                w = params[0][j]
                mu = params[1][j]
                sigma = params[2][j]
                normal_pdf = norm_pdf(X[i], mu, sigma)
                pdf += w*normal_pdf
            likelihood *=pdf     
                    
        return likelihood
            
    def get_posteriors(self,X):
        
        i = 0
        for label in self.labels:
            likelihood = 0 #likelihoods for each label
            prior = 0
            likelihood = self.get_instance_likelihood_for_label(X,label)
            prior = self.count[i]/self.len_data
            i += 1
            self.posteriors.append(likelihood*prior)
            
        return self.posteriors
    
    def predict(self, X):
        """Return the predicted class label"""
        self.posteriors = []
        self.posteriors = self.get_posteriors(X)
        max_posteriors = max(self.posteriors) 
        index_max_posteriors = self.posteriors.index(max_posteriors)
        return self.labels[index_max_posteriors]

# %%
def compute_accuracy_naive(validation_set, NaiveBayesGaussian):
    """
    Compute the accuracy of a given a testset using a NaiveBayesGaussian object.
    
    Input
        - testset: The testset for which to compute the accuracy (Numpy array). compoed by class labels
        - NaiveBayesGaussian : A NaiveBayesGaussian object capable of prediciting the class for each instance in the testset.
        
    Ouput
        - Accuracy = #Correctly Classified / #testset size
    """
    correct_count = 0
    validation_set_x, validation_set_y = validation_set[:,:2], validation_set[:,-1]
    for i in range(len(validation_set_x)):
        if NaiveBayesGaussian.predict(validation_set_x[i]) == validation_set_y[i]: # if prediction is correct increase counter
            correct_count = correct_count + 1
    return  correct_count / len(validation_set)

# %%
NB = NaiveBayesGaussian()
print(NB.fit(X_training,y_training))
# print(NB.predict(test_set.values[0]))
print(compute_accuracy_naive(test_set.values,NB))
# Out:
# {(0, 0): (array([[0.57055056],
#        [0.42944944]], dtype=float32), array([-0.46232581,  4.21942377]), array([2.6712141 , 0.84108156])), (0, 1): (array([[0.8732017],
#        [0.1267983]], dtype=float32), array([5.82497978, 3.62460542]), array([1.34891725, 0.96501046])), (1, 0): (array([[0.625],
#        [0.375]], dtype=float32), array([-3.97332168,  6.05992937]), array([0.99762219, 0.94324362])), (1, 1): (array([[0.62336683],
#        [0.37663317]], dtype=float32), array([8.93154049, 2.05388355]), array([1.39788151, 1.40329313]))}
# 0.836

# %% [markdown]
# ## Model evaluation
#
# (20 points)
#
# In this section you will build 2 models and fit them to 2 datasets
#
# First 1000 training points and first 500 test points:
# 1. Use the first 1000 points from the training set (take the first original 1000 points - before the shuffle) and the first 500 points from the test set.
# 1. Fit Logistic Regression model with the best params you found earlier.
# 1. Fit Naive Bayes model. Remember that you need to select the number of gaussians in the EM.
# 1. Print the training and test accuracies for each model.
# 1. Use the `plot_decision_regions` function to plot the decision boundaries for each model (for this you need to use the training set as the input)
# 1. Plot the cost Vs the iteration number for the Logistic Regression model
#
# Use all the training set points:
# 1. Repeat sections 2-6 for all the training set points
# 1. Provide one or two sentences on each graph explaining what you observe in the graph.
#
# #### Don't forget to label your graphs ####

# %%
## First 1000 training points X and Y seperated
x_1000 = X_training[0: 1000]
y_1000 = y_training[0: 1000]

## First 1000 training points features and labels toghether
data_500 = test_set.values[0: 500]


logisticRegressionGD_1000 = LogisticRegressionGD()
t, J = logisticRegressionGD_1000.fit(x_1000, y_1000)

NB_1000 = NaiveBayesGaussian()
NB_1000.fit(x_1000,y_1000)

logistic_accuracy_training = compute_accuracy_logistic(training_set.values[0: 1000],logisticRegressionGD_1000)
print(logistic_accuracy_training)

logistic_accuracy_test = compute_accuracy_logistic(data_500,logisticRegressionGD_1000)
print(logistic_accuracy_test)


naive_accuracy_training = compute_accuracy_naive(training_set.values[0: 1000],NB_1000 )
print(naive_accuracy_training)

naive_accuracy_test = compute_accuracy_naive(data_500,NB_1000 )
print(naive_accuracy_test)
# Out:
# 0.965
# 0.938
# 0.917
# 0.898

# %% [markdown]
# ## Open question
#
# (20 points)
#
# 1. In this homework we explored two types of models: Naive Bayes using EM, and Logistic regression.
#    1. Generate a dataset, in 3 dimensions (3 features), with 2 classes, using **only** Multivariate-Gaussians (as many as you want) that you think **Naive Bayes will work better than Logisitc Regression**.
#    2. Generate another dataset, in 3 dimensions (3 features), with 2 classes, using **only** Multivariate-Gaussians (as many as you want) that you think **Logistic Regression will work better than Naive Bayes**.
#
#    - Explain the reasoning behind each dataset.
#
# 2. Visualize the datasets.
#    You can choose one of two options for the visualization:
#     1. Plot three 2d graphs of all the features against each other (feature1 vs feature2, feature1 vs feature3, feature2 vs feature3).
#     2. Plot one 3d graph.
#
# **Important Note**
# For this question only, you may use:
# ```
# from scipy.stats import multivariate_normal
# ```

# %% [markdown]
# #### Your code and explanations here ####
